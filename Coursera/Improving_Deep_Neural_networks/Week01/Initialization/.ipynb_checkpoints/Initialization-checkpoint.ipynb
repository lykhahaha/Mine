# %% [markdown]
# # Initialization
# * We will see how different initializations lead to different results
# * A well chosen initialization can speed up the convergence of gradient descent

# %%
import warnings
def ignore_warn(*args, **kwargs):
    pass
warnings.warn = ignore_warn

import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from init_utils import *

# %matplotlib inline
plt.rcParams['figure.figsize']=(5, 4)
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# Load image dataset
train_X, train_Y, test_X, test_Y = load_dataset()

# %%
# ?load_dataset
# Out:
# Signature: load_dataset()
# Docstring: <no docstring>
# File:      f:\data-science\coursera\improving_deep_neural_networks\week01\initialization\init_utils.py
# Type:      function
